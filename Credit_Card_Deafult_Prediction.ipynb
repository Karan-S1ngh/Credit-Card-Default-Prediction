# %%
# Importing necessary libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading datasets
df = pd.read_csv('Credit_Card_Defaulter_Prediction.csv')

# %%
# viewing data
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0             0         0         0         0        Y
# 1          1000      1000         0      2000        Y
# 2          1000      1000      1000      5000        N
# 3          1200      1100      1069      1000        N
# 4         10000      9000       689       679        N
# ...         ...       ...       ...       ...      ...
# 29995      5003      3047      5000      1000        N
# 29996      8998       129         0         0        N
# 29997     22000      4200      2000      3100        Y
# 29998      1178      1926     52964      1804        Y
# 29999      1430      1000      1000      1000        N
#
# [30000 rows x 25 columns]

# %%
# viewing the first few rows of data (by default it is 5)
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0         0         0         0        Y
# 1      1000         0      2000        Y
# 2      1000      1000      5000        N
# 3      1100      1069      1000        N
# 4      9000       689       679        N
#
# [5 rows x 25 columns]

# %%
# viewing the last few rows of data (here 9)
df.tail(9)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 29991  29992     210000    1          2         1   34      3      2      2
# 29992  29993      10000    1          3         1   43      0      0      0
# 29993  29994     100000    1          1         2   38      0     -1     -1
# 29994  29995      80000    1          2         2   34      2      2      2
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29991      2  ...       2500       2500       2500         0         0
# 29992     -2  ...          0          0          0      2000         0
# 29993      0  ...      70626      69473      55004      2000    111784
# 29994      2  ...      77519      82607      81158      7000      3500
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 29991         0         0         0         0        Y
# 29992         0         0         0         0        N
# 29993      4000      3000      2000      2000        N
# 29994         0      7000         0      4000        Y
# 29995      5003      3047      5000      1000        N
# 29996      8998       129         0         0        N
# 29997     22000      4200      2000      3100        Y
# 29998      1178      1926     52964      1804        Y
# 29999      1430      1000      1000      1000        N
#
# [9 rows x 25 columns]

# %%
# counts rows and column
df.shape
# Out:
# (30000, 25)

# %%
# Check data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_1      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
#  20  PAY_AMT3   30000 non-null  int64
#  21  PAY_AMT4   30000 non-null  int64
#  22  PAY_AMT5   30000 non-null  int64
#  23  PAY_AMT6   30000 non-null  int64
#  24  default    30000 non-null  object
# dtypes: int64(24), object(1)
# memory usage: 5.7+ MB

# %%
# Describes data
df.describe().T
# .T shows it in Transpose form
# Out:
#              count           mean            std       min       25%  \
# ID         30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX        30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION  30000.0       1.842267       0.744494       1.0      1.00
# MARRIAGE   30000.0       1.557267       0.521405       1.0      1.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# PAY_1      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6  30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1   30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2   30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3   30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT4   30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT5   30000.0    4799.387633   15278.305679       0.0    252.50
# PAY_AMT6   30000.0    5215.502567   17777.465775       0.0    117.75
#
#                 50%        75%        max
# ID          15000.5   22500.25    30000.0
# LIMIT_BAL  140000.0  240000.00  1000000.0
# SEX             2.0       2.00        2.0
# EDUCATION       2.0       2.00        4.0
# MARRIAGE        2.0       2.00        3.0
# AGE            34.0      41.00       79.0
# PAY_1           0.0       0.00        8.0
# PAY_2           0.0       0.00        8.0
# PAY_3           0.0       0.00        8.0
# PAY_4           0.0       0.00        8.0
# PAY_5           0.0       0.00        8.0
# PAY_6           0.0       0.00        8.0
# BILL_AMT1   22381.5   67091.00   964511.0
# BILL_AMT2   21200.0   64006.25   983931.0
# BILL_AMT3   20088.5   60164.75  1664089.0
# BILL_AMT4   19052.0   54506.00   891586.0
# BILL_AMT5   18104.5   50190.50   927171.0
# BILL_AMT6   17071.0   49198.25   961664.0
# PAY_AMT1     2100.0    5006.00   873552.0
# PAY_AMT2     2009.0    5000.00  1684259.0
# PAY_AMT3     1800.0    4505.00   896040.0
# PAY_AMT4     1500.0    4013.25   621000.0
# PAY_AMT5     1500.0    4031.50   426529.0
# PAY_AMT6     1500.0    4000.00   528666.0

# %%
# checks for any duplicates
len(df[df.duplicated()])
# Out:
# 0

# %%
# Taking sum of null values in columns of the data
df.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# default      0
# dtype: int64

# %%
# columns of dataset
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
# Changing names of column for better understanding and simplicity (using inplace = True to retain the changes throughtout the process)
df.rename(columns = {"default" : "IsDefaulter"}, inplace = True)
df.rename(columns = {"PAY_1" : "PAY_SEPT", "PAY_2" : "PAY_AUG", "PAY_3" : "PAY_JULY", "PAY_4" : "PAY_JUNE", "PAY_5" : "PAY_MAY", "PAY_6" : "PAY_APR"}, inplace = True)
df.rename(columns = {"BILL_AMT1" : "BILL_AMT_SEPT", "BILL_AMT2" : "BILL_AMT_AUG", "BILL_AMT3" : "BILL_AMT_JULY", "BILL_AMT4" : "BILL_AMT_JUNE", "BILL_AMT5" : "BILL_AMT_MAY", "BILL_AMT6" : "BILL_AMT_APR"}, inplace = True)
df.rename(columns = {"PAY_AMT1" : "PAY_AMT_SEPT", "PAY_AMT2" : "PAY_AMT_AUG", "PAY_AMT3" : "PAY_AMT_JULY", "PAY_AMT4" : "PAY_AMT_JUNE", "PAY_AMT5" : "PAY_AMT_MAY", "PAY_AMT6" : "PAY_AMT_APR"}, inplace = True)

# %%
# Replacing values with their labels
df.replace({"SEX" : {1 : "Male", 2 : "Female"}}, inplace = True)
df.replace({"EDUCATION" : {1 : "Graduate School", 2 : "University", 3 : "High School", 4 : "Others"}}, inplace = True)
df.replace({"MARRIAGE" : {1 : "Married", 2 : "Single", 3 : "Others"}}, inplace = True)
df.replace({"IsDefaulter" : {"Y" : "Yes", "N" : "No"}}, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             30000 non-null  int64
#  1   LIMIT_BAL      30000 non-null  int64
#  2   SEX            30000 non-null  object
#  3   EDUCATION      30000 non-null  object
#  4   MARRIAGE       30000 non-null  object
#  5   AGE            30000 non-null  int64
#  6   PAY_SEPT       30000 non-null  int64
#  7   PAY_AUG        30000 non-null  int64
#  8   PAY_JULY       30000 non-null  int64
#  9   PAY_JUNE       30000 non-null  int64
#  10  PAY_MAY        30000 non-null  int64
#  11  PAY_APR        30000 non-null  int64
#  12  BILL_AMT_SEPT  30000 non-null  int64
#  13  BILL_AMT_AUG   30000 non-null  int64
#  14  BILL_AMT_JULY  30000 non-null  int64
#  15  BILL_AMT_JUNE  30000 non-null  int64
#  16  BILL_AMT_MAY   30000 non-null  int64
#  17  BILL_AMT_APR   30000 non-null  int64
#  18  PAY_AMT_SEPT   30000 non-null  int64
#  19  PAY_AMT_AUG    30000 non-null  int64
#  20  PAY_AMT_JULY   30000 non-null  int64
#  21  PAY_AMT_JUNE   30000 non-null  int64
#  22  PAY_AMT_MAY    30000 non-null  int64
#  23  PAY_AMT_APR    30000 non-null  int64
#  24  IsDefaulter    30000 non-null  object
# dtypes: int64(21), object(4)
# memory usage: 5.7+ MB

# %%
df.head()
# Out:
#    ID  LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_SEPT  PAY_AUG  \
# 0   1      20000  Female  University  Married   24         2        2
# 1   2     120000  Female  University   Single   26        -1        2
# 2   3      90000  Female  University   Single   34         0        0
# 3   4      50000  Female  University  Married   37         0        0
# 4   5      50000    Male  University  Married   57        -1        0
#
#    PAY_JULY  PAY_JUNE  ...  BILL_AMT_JUNE  BILL_AMT_MAY  BILL_AMT_APR  \
# 0        -1        -1  ...              0             0             0
# 1         0         0  ...           3272          3455          3261
# 2         0         0  ...          14331         14948         15549
# 3         0         0  ...          28314         28959         29547
# 4        -1         0  ...          20940         19146         19131
#
#    PAY_AMT_SEPT  PAY_AMT_AUG  PAY_AMT_JULY  PAY_AMT_JUNE  PAY_AMT_MAY  \
# 0             0          689             0             0            0
# 1             0         1000          1000          1000            0
# 2          1518         1500          1000          1000         1000
# 3          2000         2019          1200          1100         1069
# 4          2000        36681         10000          9000          689
#
#    PAY_AMT_APR  IsDefaulter
# 0            0          Yes
# 1         2000          Yes
# 2         5000           No
# 3         1000           No
# 4          679           No
#
# [5 rows x 25 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Finding Defaulters

# %%
# Counting defaulters
df['IsDefaulter'].value_counts()
# Out:
# IsDefaulter
# No     23365
# Yes     6635
# Name: count, dtype: int64

# %%
# value count plot for defaulters
plt.figure(figsize = (6,5))
sns.countplot(x = "IsDefaulter", data = df)
# Out:
# <Axes: xlabel='IsDefaulter', ylabel='count'>

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ### Sex

# %%
# Value count for Sex Category
df['SEX'].value_counts()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: count, dtype: int64

# %%
# count plot for Sex and with respect to Defaulters
fig, axes = plt.subplots(ncols = 2, figsize = (12,5))
sns.countplot(x = 'SEX', ax = axes[0], data = df)
sns.countplot(x = 'SEX', hue = 'IsDefaulter', ax = axes[1], data = df)
# Out:
# <Axes: xlabel='SEX', ylabel='count'>

# %% [markdown]
# ### Education

# %%
# Value count for Education Category
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# University         14030
# Graduate School    10585
# High School         4917
# Others               468
# Name: count, dtype: int64

# %%
# count plot for Education and with respect to Defaulters
fig, axes = plt.subplots(ncols = 2, figsize = (12,7))
sns.countplot(x = 'EDUCATION', ax = axes[0], data = df)
sns.countplot(x = 'EDUCATION', hue = 'IsDefaulter', ax = axes[1], data = df)
# Out:
# <Axes: xlabel='EDUCATION', ylabel='count'>

# %% [markdown]
# ### Marriage

# %%
# Value count for Education Category
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# Single     15964
# Married    13659
# Others       377
# Name: count, dtype: int64

# %%
# count plot for Education and with respect to Defaulters
fig, axes = plt.subplots(ncols = 2, figsize = (12,7))
sns.countplot(x = 'MARRIAGE', ax = axes[0], data = df)
sns.countplot(x = 'MARRIAGE', hue = 'IsDefaulter', ax = axes[1], data = df)
# Out:
# <Axes: xlabel='MARRIAGE', ylabel='count'>

# %% [markdown]
# ### Age

# %%
# Age wise distribution 
df['AGE'].value_counts()
# Out:
# AGE
# 29    1605
# 27    1477
# 28    1409
# 30    1395
# 26    1256
# 31    1217
# 25    1186
# 34    1162
# 32    1158
# 33    1146
# 24    1127
# 35    1113
# 36    1108
# 37    1041
# 39     954
# 38     944
# 23     931
# 40     870
# 41     824
# 42     794
# 44     700
# 43     670
# 45     617
# 46     570
# 22     560
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 53     325
# 52     304
# 54     247
# 55     209
# 56     178
# 58     122
# 57     122
# 59      83
# 60      67
# 21      67
# 61      56
# 62      44
# 63      31
# 64      31
# 66      25
# 65      24
# 67      16
# 69      15
# 70      10
# 68       5
# 73       4
# 72       3
# 75       3
# 71       3
# 79       1
# 74       1
# Name: count, dtype: int64

# %%
# value count for Age
plt.figure(figsize = (20,10))
sns.countplot(x = 'AGE', data = df)
# Out:
# <Axes: xlabel='AGE', ylabel='count'>

# %%
# value count for Age with respect to IsDefaulter
plt.figure(figsize = (20,10))
sns.countplot(x = 'AGE', hue = 'IsDefaulter', data = df)
# Out:
# <Axes: xlabel='AGE', ylabel='count'>

# %% [markdown]
# Below are few observations:
# - There are more female credit card holders so no of defaulters have high proportion of females.
# - No. of defaulters have a higher proportion of educated people (graduate school and university).
# - No. of defaulters have higher proportion of Singles.

# %% [markdown]
# ## Checking Correlation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             30000 non-null  int64
#  1   LIMIT_BAL      30000 non-null  int64
#  2   SEX            30000 non-null  object
#  3   EDUCATION      30000 non-null  object
#  4   MARRIAGE       30000 non-null  object
#  5   AGE            30000 non-null  int64
#  6   PAY_SEPT       30000 non-null  int64
#  7   PAY_AUG        30000 non-null  int64
#  8   PAY_JULY       30000 non-null  int64
#  9   PAY_JUNE       30000 non-null  int64
#  10  PAY_MAY        30000 non-null  int64
#  11  PAY_APR        30000 non-null  int64
#  12  BILL_AMT_SEPT  30000 non-null  int64
#  13  BILL_AMT_AUG   30000 non-null  int64
#  14  BILL_AMT_JULY  30000 non-null  int64
#  15  BILL_AMT_JUNE  30000 non-null  int64
#  16  BILL_AMT_MAY   30000 non-null  int64
#  17  BILL_AMT_APR   30000 non-null  int64
#  18  PAY_AMT_SEPT   30000 non-null  int64
#  19  PAY_AMT_AUG    30000 non-null  int64
#  20  PAY_AMT_JULY   30000 non-null  int64
#  21  PAY_AMT_JUNE   30000 non-null  int64
#  22  PAY_AMT_MAY    30000 non-null  int64
#  23  PAY_AMT_APR    30000 non-null  int64
#  24  IsDefaulter    30000 non-null  object
# dtypes: int64(21), object(4)
# memory usage: 5.7+ MB

# %%
df.corr(numeric_only = True)
# Out:
#                      ID  LIMIT_BAL       AGE  PAY_SEPT   PAY_AUG  PAY_JULY  \
# ID             1.000000   0.026179  0.018678 -0.030575 -0.011215 -0.018494
# LIMIT_BAL      0.026179   1.000000  0.144713 -0.271214 -0.296382 -0.286123
# AGE            0.018678   0.144713  1.000000 -0.039447 -0.050148 -0.053048
# PAY_SEPT      -0.030575  -0.271214 -0.039447  1.000000  0.672164  0.574245
# PAY_AUG       -0.011215  -0.296382 -0.050148  0.672164  1.000000  0.766552
# PAY_JULY      -0.018494  -0.286123 -0.053048  0.574245  0.766552  1.000000
# PAY_JUNE      -0.002735  -0.267460 -0.049722  0.538841  0.662067  0.777359
# PAY_MAY       -0.022199  -0.249411 -0.053826  0.509426  0.622780  0.686775
# PAY_APR       -0.020270  -0.235195 -0.048773  0.474553  0.575501  0.632684
# BILL_AMT_SEPT  0.019389   0.285430  0.056239  0.187068  0.234887  0.208473
# BILL_AMT_AUG   0.017982   0.278314  0.054283  0.189859  0.235257  0.237295
# BILL_AMT_JULY  0.024354   0.283236  0.053710  0.179785  0.224146  0.227494
# BILL_AMT_JUNE  0.040351   0.293988  0.051353  0.179125  0.222237  0.227202
# BILL_AMT_MAY   0.016705   0.295562  0.049345  0.180635  0.221348  0.225145
# BILL_AMT_APR   0.016730   0.290389  0.047613  0.176980  0.219403  0.222327
# PAY_AMT_SEPT   0.009742   0.195236  0.026147 -0.079269 -0.080701  0.001295
# PAY_AMT_AUG    0.008406   0.178408  0.021785 -0.070101 -0.058990 -0.066793
# PAY_AMT_JULY   0.039151   0.210167  0.029247 -0.070561 -0.055901 -0.053311
# PAY_AMT_JUNE   0.007793   0.203242  0.021379 -0.064005 -0.046858 -0.046067
# PAY_AMT_MAY    0.000652   0.217202  0.022850 -0.058190 -0.037093 -0.035863
# PAY_AMT_APR    0.003000   0.219595  0.019478 -0.058673 -0.036500 -0.035861
#
#                PAY_JUNE   PAY_MAY   PAY_APR  BILL_AMT_SEPT  ...  \
# ID            -0.002735 -0.022199 -0.020270       0.019389  ...
# LIMIT_BAL     -0.267460 -0.249411 -0.235195       0.285430  ...
# AGE           -0.049722 -0.053826 -0.048773       0.056239  ...
# PAY_SEPT       0.538841  0.509426  0.474553       0.187068  ...
# PAY_AUG        0.662067  0.622780  0.575501       0.234887  ...
# PAY_JULY       0.777359  0.686775  0.632684       0.208473  ...
# PAY_JUNE       1.000000  0.819835  0.716449       0.202812  ...
# PAY_MAY        0.819835  1.000000  0.816900       0.206684  ...
# PAY_APR        0.716449  0.816900  1.000000       0.207373  ...
# BILL_AMT_SEPT  0.202812  0.206684  0.207373       1.000000  ...
# BILL_AMT_AUG   0.225816  0.226913  0.226924       0.951484  ...
# BILL_AMT_JULY  0.244983  0.243335  0.241181       0.892279  ...
# BILL_AMT_JUNE  0.245917  0.271915  0.266356       0.860272  ...
# BILL_AMT_MAY   0.242902  0.269783  0.290894       0.829779  ...
# BILL_AMT_APR   0.239154  0.262509  0.285091       0.802650  ...
# PAY_AMT_SEPT  -0.009362 -0.006089 -0.001496       0.140277  ...
# PAY_AMT_AUG   -0.001944 -0.003191 -0.005223       0.099355  ...
# PAY_AMT_JULY  -0.069235  0.009062  0.005834       0.156887  ...
# PAY_AMT_JUNE  -0.043461 -0.058299  0.019018       0.158303  ...
# PAY_AMT_MAY   -0.033590 -0.033337 -0.046434       0.167026  ...
# PAY_AMT_APR   -0.026565 -0.023027 -0.025299       0.179341  ...
#
#                BILL_AMT_JULY  BILL_AMT_JUNE  BILL_AMT_MAY  BILL_AMT_APR  \
# ID                  0.024354       0.040351      0.016705      0.016730
# LIMIT_BAL           0.283236       0.293988      0.295562      0.290389
# AGE                 0.053710       0.051353      0.049345      0.047613
# PAY_SEPT            0.179785       0.179125      0.180635      0.176980
# PAY_AUG             0.224146       0.222237      0.221348      0.219403
# PAY_JULY            0.227494       0.227202      0.225145      0.222327
# PAY_JUNE            0.244983       0.245917      0.242902      0.239154
# PAY_MAY             0.243335       0.271915      0.269783      0.262509
# PAY_APR             0.241181       0.266356      0.290894      0.285091
# BILL_AMT_SEPT       0.892279       0.860272      0.829779      0.802650
# BILL_AMT_AUG        0.928326       0.892482      0.859778      0.831594
# BILL_AMT_JULY       1.000000       0.923969      0.883910      0.853320
# BILL_AMT_JUNE       0.923969       1.000000      0.940134      0.900941
# BILL_AMT_MAY        0.883910       0.940134      1.000000      0.946197
# BILL_AMT_APR        0.853320       0.900941      0.946197      1.000000
# PAY_AMT_SEPT        0.244335       0.233012      0.217031      0.199965
# PAY_AMT_AUG         0.316936       0.207564      0.181246      0.172663
# PAY_AMT_JULY        0.130011       0.300023      0.252305      0.233770
# PAY_AMT_JUNE        0.143405       0.130191      0.293118      0.250237
# PAY_AMT_MAY         0.179712       0.160433      0.141574      0.307729
# PAY_AMT_APR         0.182326       0.177637      0.164184      0.115494
#
#                PAY_AMT_SEPT  PAY_AMT_AUG  PAY_AMT_JULY  PAY_AMT_JUNE  \
# ID                 0.009742     0.008406      0.039151      0.007793
# LIMIT_BAL          0.195236     0.178408      0.210167      0.203242
# AGE                0.026147     0.021785      0.029247      0.021379
# PAY_SEPT          -0.079269    -0.070101     -0.070561     -0.064005
# PAY_AUG           -0.080701    -0.058990     -0.055901     -0.046858
# PAY_JULY           0.001295    -0.066793     -0.053311     -0.046067
# PAY_JUNE          -0.009362    -0.001944     -0.069235     -0.043461
# PAY_MAY           -0.006089    -0.003191      0.009062     -0.058299
# PAY_APR           -0.001496    -0.005223      0.005834      0.019018
# BILL_AMT_SEPT      0.140277     0.099355      0.156887      0.158303
# BILL_AMT_AUG       0.280365     0.100851      0.150718      0.147398
# BILL_AMT_JULY      0.244335     0.316936      0.130011      0.143405
# BILL_AMT_JUNE      0.233012     0.207564      0.300023      0.130191
# BILL_AMT_MAY       0.217031     0.181246      0.252305      0.293118
# BILL_AMT_APR       0.199965     0.172663      0.233770      0.250237
# PAY_AMT_SEPT       1.000000     0.285576      0.252191      0.199558
# PAY_AMT_AUG        0.285576     1.000000      0.244770      0.180107
# PAY_AMT_JULY       0.252191     0.244770      1.000000      0.216325
# PAY_AMT_JUNE       0.199558     0.180107      0.216325      1.000000
# PAY_AMT_MAY        0.148459     0.180908      0.159214      0.151830
# PAY_AMT_APR        0.185735     0.157634      0.162740      0.157834
#
#                PAY_AMT_MAY  PAY_AMT_APR
# ID                0.000652     0.003000
# LIMIT_BAL         0.217202     0.219595
# AGE               0.022850     0.019478
# PAY_SEPT         -0.058190    -0.058673
# PAY_AUG          -0.037093    -0.036500
# PAY_JULY         -0.035863    -0.035861
# PAY_JUNE         -0.033590    -0.026565
# PAY_MAY          -0.033337    -0.023027
# PAY_APR          -0.046434    -0.025299
# BILL_AMT_SEPT     0.167026     0.179341
# BILL_AMT_AUG      0.157957     0.174256
# BILL_AMT_JULY     0.179712     0.182326
# BILL_AMT_JUNE     0.160433     0.177637
# BILL_AMT_MAY      0.141574     0.164184
# BILL_AMT_APR      0.307729     0.115494
# PAY_AMT_SEPT      0.148459     0.185735
# PAY_AMT_AUG       0.180908     0.157634
# PAY_AMT_JULY      0.159214     0.162740
# PAY_AMT_JUNE      0.151830     0.157834
# PAY_AMT_MAY       1.000000     0.154896
# PAY_AMT_APR       0.154896     1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize = (20,18))
sns.heatmap(df.corr(numeric_only = True), cmap = 'coolwarm')
plt.show()

# %% [markdown]
# ## One Hot Encoding

# %%
# label encoding
encode_num = {"SEX" : {'Female' : 0, 'Male' : 1}, 'IsDefaulter' : {'No' : 0, 'Yes' : 1}}
df = df.replace(encode_num)

# %%
# check for changed labels
df.head()
# Out:
#    ID  LIMIT_BAL  SEX   EDUCATION MARRIAGE  AGE  PAY_SEPT  PAY_AUG  PAY_JULY  \
# 0   1      20000    0  University  Married   24         2        2        -1
# 1   2     120000    0  University   Single   26        -1        2         0
# 2   3      90000    0  University   Single   34         0        0         0
# 3   4      50000    0  University  Married   37         0        0         0
# 4   5      50000    1  University  Married   57        -1        0        -1
#
#    PAY_JUNE  ...  BILL_AMT_JUNE  BILL_AMT_MAY  BILL_AMT_APR  PAY_AMT_SEPT  \
# 0        -1  ...              0             0             0             0
# 1         0  ...           3272          3455          3261             0
# 2         0  ...          14331         14948         15549          1518
# 3         0  ...          28314         28959         29547          2000
# 4         0  ...          20940         19146         19131          2000
#
#    PAY_AMT_AUG  PAY_AMT_JULY  PAY_AMT_JUNE  PAY_AMT_MAY  PAY_AMT_APR  \
# 0          689             0             0            0            0
# 1         1000          1000          1000            0         2000
# 2         1500          1000          1000         1000         5000
# 3         2019          1200          1100         1069         1000
# 4        36681         10000          9000          689          679
#
#    IsDefaulter
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (30000, 25)

# %%
# creating dummy variables
df = pd.get_dummies(df, columns = ['EDUCATION', 'MARRIAGE'])

# %%
df.shape
# Out:
# (30000, 30)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  AGE  PAY_SEPT  PAY_AUG  PAY_JULY  PAY_JUNE  PAY_MAY  \
# 0   1      20000    0   24         2        2        -1        -1       -2
# 1   2     120000    0   26        -1        2         0         0        0
# 2   3      90000    0   34         0        0         0         0        0
# 3   4      50000    0   37         0        0         0         0        0
# 4   5      50000    1   57        -1        0        -1         0        0
#
#    PAY_APR  ...  PAY_AMT_MAY  PAY_AMT_APR  IsDefaulter  \
# 0       -2  ...            0            0            1
# 1        2  ...            0         2000            1
# 2        0  ...         1000         5000            0
# 3        0  ...         1069         1000            0
# 4        0  ...          689          679            0
#
#    EDUCATION_Graduate School  EDUCATION_High School  EDUCATION_Others  \
# 0                      False                  False             False
# 1                      False                  False             False
# 2                      False                  False             False
# 3                      False                  False             False
# 4                      False                  False             False
#
#    EDUCATION_University  MARRIAGE_Married  MARRIAGE_Others  MARRIAGE_Single
# 0                  True              True            False            False
# 1                  True             False            False             True
# 2                  True             False            False             True
# 3                  True              True            False            False
# 4                  True              True            False            False
#
# [5 rows x 30 columns]

# %%
# Removing education and marriage others columns
df.drop(['EDUCATION_Others', 'MARRIAGE_Others'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (30000, 28)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  AGE  PAY_SEPT  PAY_AUG  PAY_JULY  PAY_JUNE  PAY_MAY  \
# 0   1      20000    0   24         2        2        -1        -1       -2
# 1   2     120000    0   26        -1        2         0         0        0
# 2   3      90000    0   34         0        0         0         0        0
# 3   4      50000    0   37         0        0         0         0        0
# 4   5      50000    1   57        -1        0        -1         0        0
#
#    PAY_APR  ...  PAY_AMT_JULY  PAY_AMT_JUNE  PAY_AMT_MAY  PAY_AMT_APR  \
# 0       -2  ...             0             0            0            0
# 1        2  ...          1000          1000            0         2000
# 2        0  ...          1000          1000         1000         5000
# 3        0  ...          1200          1100         1069         1000
# 4        0  ...         10000          9000          689          679
#
#    IsDefaulter  EDUCATION_Graduate School  EDUCATION_High School  \
# 0            1                      False                  False
# 1            1                      False                  False
# 2            0                      False                  False
# 3            0                      False                  False
# 4            0                      False                  False
#
#    EDUCATION_University  MARRIAGE_Married  MARRIAGE_Single
# 0                  True              True            False
# 1                  True             False             True
# 2                  True             False             True
# 3                  True              True            False
# 4                  True              True            False
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Handling Class Imbalance (Using SMOTE)
# ### SMOTE ( Synthetic Minority Oversampling Technique)

# %%
# importing SMOTE to handle class imbalance
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()

# %%
# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(df[(i for i in list(df.describe(include = 'all').columns) if i != 'IsDefaulter')], df['IsDefaulter'])

# %%
print('Original unbalanced dataset shape', len(df))
print('Resampled balanced dataset shape', len(y_smote))
# Out:
# Original unbalanced dataset shape 30000
# Resampled balanced dataset shape 46730

# %%
# Creating new Data Frame from balanced dataset after using SMOTE
balanced_df = pd.DataFrame(x_smote, columns = [i for i in list(df.describe(include = 'all').columns) if i != 'IsDefaulter'])

# %%
# adding target variable to new created Data Frame
balanced_df['IsDefaulter'] = y_smote

# %%
balanced_df['IsDefaulter'].value_counts()
# Out:
# IsDefaulter
# 1    23365
# 0    23365
# Name: count, dtype: int64

# %%
balanced_df.shape
# Out:
# (46730, 28)

# %%
# removing feature ID from dataset
balanced_df.drop(['ID'], axis = 1, inplace = True)

# %%
# final dataset
balanced_df
# Out:
#        LIMIT_BAL  SEX  AGE  PAY_SEPT  PAY_AUG  PAY_JULY  PAY_JUNE  PAY_MAY  \
# 0          20000    0   24         2        2        -1        -1       -2
# 1         120000    0   26        -1        2         0         0        0
# 2          90000    0   34         0        0         0         0        0
# 3          50000    0   37         0        0         0         0        0
# 4          50000    1   57        -1        0        -1         0        0
# ...          ...  ...  ...       ...      ...       ...       ...      ...
# 46725      50000    1   25         1        1         0         0        0
# 46726     150000    0   35         1        1         1         0        0
# 46727     150000    0   31         1        0         0         0       -1
# 46728      80000    0   27         1        2         0         0        0
# 46729     181901    1   44         0        0         0         0        0
#
#        PAY_APR  BILL_AMT_SEPT  ...  PAY_AMT_JULY  PAY_AMT_JUNE  PAY_AMT_MAY  \
# 0           -2           3913  ...             0             0            0
# 1            2           2682  ...          1000          1000            0
# 2            0          29239  ...          1000          1000         1000
# 3            0          46990  ...          1200          1100         1069
# 4            0           8617  ...         10000          9000          689
# ...        ...            ...  ...           ...           ...          ...
# 46725        0          51695  ...           968          1163         1051
# 46726        0         134653  ...          5001          5047         4906
# 46727       -1           2656  ...             0           687          687
# 46728       -1           3890  ...           530           360         2557
# 46729        0          84945  ...          1518         54015        32579
#
#        PAY_AMT_APR  EDUCATION_Graduate School  EDUCATION_High School  \
# 0                0                      False                  False
# 1             2000                      False                  False
# 2             5000                      False                  False
# 3             1000                      False                  False
# 4              679                      False                  False
# ...            ...                        ...                    ...
# 46725         1130                      False                  False
# 46726         3186                      False                  False
# 46727          458                      False                  False
# 46728         1820                      False                  False
# 46729         2942                      False                  False
#
#        EDUCATION_University  MARRIAGE_Married  MARRIAGE_Single  IsDefaulter
# 0                      True              True            False            1
# 1                      True             False             True            1
# 2                      True             False             True            0
# 3                      True              True            False            0
# 4                      True              True            False            0
# ...                     ...               ...              ...          ...
# 46725                  True             False            False            1
# 46726                 False              True            False            1
# 46727                  True             False            False            1
# 46728                  True             False            False            1
# 46729                 False             False            False            1
#
# [46730 rows x 27 columns]

# %%
# Separating dependent and independent variables
x = balanced_df[(list(i for i in list(balanced_df.describe(include = 'all').columns) if i != 'IsDefaulter'))]
y = balanced_df['IsDefaulter']

# %%
x.shape
# Out:
# (46730, 26)

# %%
y.shape
# Out:
# (46730,)

# %%
x
# Out:
#        LIMIT_BAL  SEX  AGE  PAY_SEPT  PAY_AUG  PAY_JULY  PAY_JUNE  PAY_MAY  \
# 0          20000    0   24         2        2        -1        -1       -2
# 1         120000    0   26        -1        2         0         0        0
# 2          90000    0   34         0        0         0         0        0
# 3          50000    0   37         0        0         0         0        0
# 4          50000    1   57        -1        0        -1         0        0
# ...          ...  ...  ...       ...      ...       ...       ...      ...
# 46725      50000    1   25         1        1         0         0        0
# 46726     150000    0   35         1        1         1         0        0
# 46727     150000    0   31         1        0         0         0       -1
# 46728      80000    0   27         1        2         0         0        0
# 46729     181901    1   44         0        0         0         0        0
#
#        PAY_APR  BILL_AMT_SEPT  ...  PAY_AMT_AUG  PAY_AMT_JULY  PAY_AMT_JUNE  \
# 0           -2           3913  ...          689             0             0
# 1            2           2682  ...         1000          1000          1000
# 2            0          29239  ...         1500          1000          1000
# 3            0          46990  ...         2019          1200          1100
# 4            0           8617  ...        36681         10000          9000
# ...        ...            ...  ...          ...           ...           ...
# 46725        0          51695  ...         1372           968          1163
# 46726        0         134653  ...          312          5001          5047
# 46727       -1           2656  ...         1099             0           687
# 46728       -1           3890  ...         2377           530           360
# 46729        0          84945  ...        48408          1518         54015
#
#        PAY_AMT_MAY  PAY_AMT_APR  EDUCATION_Graduate School  \
# 0                0            0                      False
# 1                0         2000                      False
# 2             1000         5000                      False
# 3             1069         1000                      False
# 4              689          679                      False
# ...            ...          ...                        ...
# 46725         1051         1130                      False
# 46726         4906         3186                      False
# 46727          687          458                      False
# 46728         2557         1820                      False
# 46729        32579         2942                      False
#
#        EDUCATION_High School  EDUCATION_University  MARRIAGE_Married  \
# 0                      False                  True              True
# 1                      False                  True             False
# 2                      False                  True             False
# 3                      False                  True              True
# 4                      False                  True              True
# ...                      ...                   ...               ...
# 46725                  False                  True             False
# 46726                  False                 False              True
# 46727                  False                  True             False
# 46728                  False                  True             False
# 46729                  False                 False             False
#
#        MARRIAGE_Single
# 0                False
# 1                 True
# 2                 True
# 3                False
# 4                False
# ...                ...
# 46725            False
# 46726            False
# 46727            False
# 46728            False
# 46729            False
#
# [46730 rows x 26 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 46725    1
# 46726    1
# 46727    1
# 46728    1
# 46729    1
# Name: IsDefaulter, Length: 46730, dtype: int64

# %% [markdown]
# # Data Transformation

# %%
# importing libraries for data transformation
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)

# %% [markdown]
# ### Train Test Splitting

# %%
# importing libraries for splitting data into training and testing sets
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42, stratify = y)

# %%
x_train.shape
# Out:
# (32711, 26)

# %%
x_test.shape
# Out:
# (14019, 26)

# %% [markdown]
# # Model Implementation

# %% [markdown]
# ### Logistic Regression Model

# %%
# importing logistic regression and evaluation metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

# %%
# fiting data into logistic regression model
logi = LogisticRegression(fit_intercept = True, max_iter = 10000)
logi.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
# class precision of y
y_pred_logi = logi.predict(x_test)
y_train_pred_logi = logi.predict(x_train)

# %%
# getting all score for logistic regression
train_accuracy_logi = round(accuracy_score(y_train_pred_logi, y_train), 3)
accuracy_logi = round(accuracy_score(y_pred_logi, y_test), 3)
precision_score_logi = round(precision_score(y_pred_logi, y_test), 3)
recall_score_logi = round(recall_score(y_pred_logi, y_test), 3)
f1_score_logi = round(f1_score(y_pred_logi, y_test), 3)

# %%
print('The accuracy on train data is : ', train_accuracy_logi)
print('The accuracy on test data is : ', accuracy_logi)
print('The precision on test data is : ', precision_score_logi)
print('The recall on test data is : ', recall_score_logi)
print('The f1 score on test data is : ', f1_score_logi)
# Out:
# The accuracy on train data is :  0.815
# The accuracy on test data is :  0.814
# The precision on test data is :  0.718
# The recall on test data is :  0.889
# The f1 score on test data is :  0.794

# %%
# Confusion Matrix
labels = ['Not Defaulter', 'Defaulter']
cm_logi = confusion_matrix(y_test, y_pred_logi)
print(cm_logi)
# Out:
# [[6380  630]
#  [1978 5031]]

# %%
# plotting confusion matrix
ax = plt.subplot()
sns.heatmap(cm_logi, annot = True, ax = ax)

# Labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
# Out:
# [Text(0, 0.5, 'Not Defaulter'), Text(0, 1.5, 'Defaulter')]
